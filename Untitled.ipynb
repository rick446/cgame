# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.r_[0:1:20j]
ys = (-4 * (xs - 0.5)**2 + 1) * 6
plt.plot(xs, ys)

# %%
ys[0]
# Out:
# 0.0

# %%
ys[-1]
# Out:
# 0.0
